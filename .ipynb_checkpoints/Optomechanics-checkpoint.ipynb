# %% [markdown]
# # Optomechanics

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.linalg import eigh_tridiagonal

# %% [markdown]
# ## QuTip
#
# System Parameters (in units of wm)
#
# https://github.com/qutip/qutip-notebooks/blob/master/examples/optomechanical-steadystate.ipynb

# %%
from qutip import tensor, destroy, qeye

# System Parameters (in units of wm)
#-----------------------------------
Nc = 20                     # Number of cavity states
Nm = 30                     # Number of mech states
kappa = 0.3                 # Cavity damping rate
E = 0.1                     # Driving Amplitude         
g0 = 2.4*kappa              # Coupling strength
Qm = 1e4                    # Mech quality factor
gamma = 1/Qm                # Mech damping rate
n_th = 1                    # Mech bath temperature
delta = -0.43               # Detuning



# Operators
#----------

## This choice does not lead to tridiagonal matrix
# a = tensor(qeye(Nm), destroy(Nc))
# b = tensor(destroy(Nm), qeye(Nc), )

# This is a tri-diagonal matrix 
a = tensor(destroy(Nc), qeye(Nm))
b = tensor(qeye(Nc), destroy(Nm))

num_b = b.dag()*b
num_a = a.dag()*a

# Hamiltonian
#------------

H = -delta * num_a + num_b + g0 * (b.dag() + b) * num_a #+ E*(a.dag()+a)

# from qutip.visualization import hinton
# hinton(num_a)

# %%
import time

t0 = time.time()

qutip_energies = H.eigenenergies()

print("Qutip running time {}".format(time.time() - t0))
# Out:
# Qutip running time 0.2013089656829834

# %% [markdown]
# ## Tridiagonalization method

# %%
na_range = np.arange(Nc)
nb_range = np.arange(Nm)

# cartesian product 
na = np.repeat(na_range, nb_range.size)
nb = np.tile(nb_range, na_range.size)

# define nb after the  na <-> nb swap
nb_swaped = np.tile(na_range, nb_range.size)

# %%
#na, nb

# %%
t0 = time.time()

tridiag_energies = eigh_tridiagonal(
    -delta * na + nb, g0 * (na * np.sqrt(nb))[1:],
    eigvals_only = True
)

print("Tridiag running time {}".format(time.time() - t0))
# Out:
# Tridiag running time 0.0011148452758789062

# %% [markdown]
# ## Comparison

# %%
plt.plot(qutip_energies, ".", label="qutip")
plt.plot(tridiag_energies, ".", label="tridiaginalization")
plt.xlabel("index")
plt.ylabel("Energy")
plt.legend()
plt.show()

# %%
plt.plot(np.abs(qutip_energies - tridiag_energies), ".", label="qutip - tridiag")
plt.xlabel("index")
plt.ylabel("|Energy via qutip - Energy via tridiag|")

plt.show()

# %% [markdown]
# ## Getting the unitary operator via split operator
#
# ### Qutip

# %%
dt = 1.

U_qutip = (1j * dt * H).expm() * (1j * dt * E * (a.dag() + a)).expm()

# %% [markdown]
# ### tridiagonal

# %%
lambdas, v = eigh_tridiagonal(
    -delta * na + nb, g0 * (na * np.sqrt(nb))[1:]
)

U_H = v @ np.diag(np.exp(1j * dt * lambdas)) @ v.T

# %% [markdown]
# Check that the result from the two methods coincide

# %%
np.allclose(
    (1j * dt * H).expm().data.toarray(), 
    U_H
)
# Out:
# True

# %%
# Swap na <-> nb to get the tridiagonal matrix

eigenvals, v = eigh_tridiagonal(
    np.zeros(Nc * Nm), E * np.sqrt(nb_swaped)[1:],
)

U_int = v @ np.diag(np.exp(1j * dt * eigenvals)) @ v.T

# reindexing to permute na <-> nb
indx = na + nb * Nc

U_int = np.ascontiguousarray(U_int[indx, :][:, indx])

# %% [markdown]
# Check that the result from the two methods coincide

# %%
np.allclose(
    (1j * dt * E * (a.dag() + a)).expm().data.toarray(), 
    U_int
)
# Out:
# True

# %%
U_tridiagonal = U_H @ U_int

np.allclose(
    U_tridiagonal,
    U_qutip.data.toarray()
)
# Out:
# True
